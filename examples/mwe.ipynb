# %% [markdown]
# ## Minimum working example
# This notebook runs a minimum working example with growbikenet

# %% [markdown]
# ### Import growbikenet

# %%
import growbikenet as gbn

# %% [markdown]
# ### Run growbikenet with example city Oelde and rank by betweenness centrality

# %%
a_edges = gbn.growbikenet(
    city_name="Oelde",
    proj_crs = '3857',
    ranking = 'betweenness_centrality',
    export_plots = False,
    export_video = False
)

# %% [markdown]
# data is saved in .examples/
