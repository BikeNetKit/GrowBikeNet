# %% [markdown]
# # Minimum working example
# This notebook runs a minimum working example with growbikenet.

# %% [markdown]
# ## Import growbikenet

# %% [markdown]
# The standard way of importing growbikenet:

# %%
import growbikenet as gbn

# %% [markdown]
# ## Run growbikenet on example city

# %%
edges_ordered = gbn.growbikenet("Lyon")
# Out:
# ==============================================
# RUNNING GROWBIKENET FOR CITY: Lyon
# betweenness | auto | from scratch
# ----------------------------------------------╮
# Downloading OSM data   : 100%|████████████████| 1/1 [00:05<00:00,  5.70s/network]
# Creating seed points   : 100%|████████████████| 3/3 [00:00<00:00,  6.33step/s]
# Triangulation          : 100%|████████████████| 1/1 [00:00<00:00, 884.13step/s]
# Routing                : 100%|████████████████| 3/3 [00:00<00:00, 10.58step/s]
# Computing edge metrics : 100%|████████████████| 2/2 [00:00<00:00, 123.20step/s]
# Removing edge overlaps : 100%|████████████████| 102/102 [00:00<00:00, 358.81edge/s]
# Exporting data         : 100%|████████████████| 1/1 [00:00<00:00, 14.84step/s]
# ----------------------------------------------╯
# Data exported to ./results/
# ----------------------------------------------
# FINISHED IN 0:00:07
# ==============================================

# %% [markdown]
# ## Explore results

# %% [markdown]
# See the contents of the resulting geodataframe:

# %%
edges_ordered.head()
# Out:
#    betweenness                                           geometry    source  \
# 0     0.170697  LINESTRING (4.85175 45.75459, 4.85166 45.75459...  26106485
# 1     0.137980  LINESTRING (4.85215 45.74397, 4.85199 45.74419...  25258525
# 2     0.113798  LINESTRING (4.83428 45.76462, 4.83429 45.76476...  26106485
# 3     0.112376  LINESTRING (4.8687 45.74535, 4.86863 45.74537,...  25334263
# 4     0.110953  LINESTRING (4.83517 45.75474, 4.83475 45.75423...  34967266
#
#        target  ordering  length  length_cumulative
# 0    25258525         0    3193               3193
# 1  3404990017         1    1855               5049
# 2   253414917         2    2318               7367
# 3    25258525         3    2227               9595
# 4  2749132868         4    2617              12212

# %% [markdown]
# Explore the results interactively:

# %%
edges_ordered.explore(tiles="CartoDB Positron", # background map
                     style_kwds={"weight": 3, "color": "#096a51"}, # thick green lines
                    )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8794aac5cb35b0ef9cc99ec968885fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8794aac5cb35b0ef9cc99ec968885fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8794aac5cb35b0ef9cc99ec968885fb = L.map(
#                 &quot;map_f8794aac5cb35b0ef9cc99ec968885fb&quot;,
#                 {
#                     center: [45.760374299999995, 4.8309505999999995],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f8794aac5cb35b0ef9cc99ec968885fb);
#
#
#
#
#
#             var tile_layer_b338e119a734fe932beb5c0d855e12ec = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b338e119a734fe932beb5c0d855e12ec.addTo(map_f8794aac5cb35b0ef9cc99ec968885fb);
#
#
#             map_f8794aac5cb35b0ef9cc99ec968885fb.fitBounds(
#                 [[45.719002399999994, 4.7748836], [45.8017462, 4.8870176]],
#                 {}
#             );
#
#
#         function geo_json_b672adaea9d8fab8aaa4f2d53443c425_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#096a51&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 3};
#             }
#         }
#         function geo_json_b672adaea9d8fab8aaa4f2d53443c425_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b672adaea9d8fab8aaa4f2d53443c425_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_b672adaea9d8fab8aaa4f2d53443c425_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b672adaea9d8fab8aaa4f2d53443c425_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b672adaea9d8fab8aaa4f2d53443c425.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b672adaea9d8fab8aaa4f2d53443c425_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b672adaea9d8fab8aaa4f2d53443c425 = L.geoJson(null, {
#                 onEachFeature: geo_json_b672adaea9d8fab8aaa4f2d53443c425_onEachFeature,
#
#                 style: geo_json_b672adaea9d8fab8aaa4f2d53443c425_styler,
#                 pointToLayer: geo_json_b672adaea9d8fab8aaa4f2d53443c425_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b672adaea9d8fab8aaa4f2d53443c425_add (data) {
#             geo_json_b672adaea9d8fab8aaa4f2d53443c425
#                 .addData(data);
#         }
#             geo_json_b672adaea9d8fab8aaa4f2d53443c425_add({&quot;bbox&quot;: [4.7748836, 45.719002399999994, 4.8870176, 45.8017462], &quot;features&quot;: [{&quot;bbox&quot;: [4.834195399999999, 45.75456499999999, 4.851747799999999, 45.764621699999985], &quot;geometry&quot;: {&quot;coordinates&quot;: [[4.851747799999999, 45.75459289999999], [4.8516634, 45.7545851], [4.

# %% [markdown]
# See the [Usage docs](https://docs.bikenetkit.org/GrowBikeNet/usage/) for detailed explanations.
