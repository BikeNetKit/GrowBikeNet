# %% [markdown]
# # Minimum working example
# This notebook runs a minimum working example with growbikenet.

# %% [markdown]
# ## Import growbikenet

# %% [markdown]
# The standard way of importing growbikenet:

# %%
import growbikenet as gbn

# %% [markdown]
# ## Run growbikenet on example city

# %%
edges_ordered = gbn.growbikenet("Lyon")
# Out:
# ==============================================
# RUNNING GROWBIKENET FOR CITY: Lyon
# betweenness | auto | from scratch
# ----------------------------------------------╮
# Downloading OSM data   :   0%|                | 0/1 [00:00<?, ?network/s]
# Creating seed points   :   0%|                | 0/3 [00:00<?, ?step/s]
# Triangulation          :   0%|                | 0/1 [00:00<?, ?step/s]
# Routing                :   0%|                | 0/3 [00:00<?, ?step/s]
# Computing edge metrics :   0%|                | 0/2 [00:00<?, ?step/s]
# Rerouting              :   0%|                | 0/42 [00:00<?, ?edge/s]
# Removing edge overlaps :   0%|                | 0/42 [00:00<?, ?edge/s]
# Exporting data         :   0%|                | 0/1 [00:00<?, ?file/s]
# ----------------------------------------------╯
# Data exported to ./results/
# ----------------------------------------------
# FINISHED IN 0:00:08
# ==============================================

# %% [markdown]
# ## Explore results

# %% [markdown]
# See the contents of the resulting geodataframe:

# %%
edges_ordered.head()
# Out:
#    betweenness                                           geometry  \
# 0     0.215686  LINESTRING (4.85595 45.7328, 4.85594 45.73276,...
# 1     0.117647  LINESTRING (4.83139 45.76126, 4.83136 45.7612,...
# 2     0.117647  LINESTRING (4.85383 45.76229, 4.8527 45.76219,...
# 3     0.111111  LINESTRING (4.84111 45.76129, 4.84113 45.76141...
# 4     0.098039  LINESTRING (4.80882 45.79182, 4.80878 45.79176...
#
#         source       target  ordering  length  length_cumulative
# 0    959373357  11942296886         0    2036               2036
# 1  13533881767    959373357         1    2660               4696
# 2    959373357   2139361034         2    1960               6657
# 3    959373357  11571529610         3    2548               9205
# 4   2139361034     25303800         4    4411              13617

# %% [markdown]
# Explore the results interactively:

# %%
edges_ordered.explore(
    tiles="CartoDB Positron", # background map
    style_kwds={"weight": 3, "color": "#096a51"}, # thick green lines
)
# Out:
# /Users/mszell/Github/BikeNetKit/GrowBikeNet/.pixi/envs/default/lib/python3.14/site-packages/geopandas/explore.py:388: UserWarning: CartoDB tiles now require an API key. Please provide one to continue using the tiles. You can request the key at https://carto.com/basemaps/apikey/.
#   tiles = tiles.build_url(scale_factor="{r}")
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e8da9ef34833a0e3cfca096b280ad69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e8da9ef34833a0e3cfca096b280ad69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e8da9ef34833a0e3cfca096b280ad69 = L.map(
#                 &quot;map_8e8da9ef34833a0e3cfca096b280ad69&quot;,
#                 {
#                     center: [45.76053595, 4.832166900000001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8e8da9ef34833a0e3cfca096b280ad69);
#
#
#
#
#
#             var tile_layer_0032292e76b17e5d57ae6b6ff40ee08c = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0032292e76b17e5d57ae6b6ff40ee08c.addTo(map_8e8da9ef34833a0e3cfca096b280ad69);
#
#
#             map_8e8da9ef34833a0e3cfca096b280ad69.fitBounds(
#                 [[45.7292496, 4.7853145], [45.79182229999999, 4.879019300000001]],
#                 {}
#             );
#
#
#         function geo_json_681ace4feffef46dae3b48340931cc1e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#096a51&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 3};
#             }
#         }
#         function geo_json_681ace4feffef46dae3b48340931cc1e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_681ace4feffef46dae3b48340931cc1e_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_681ace4feffef46dae3b48340931cc1e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_681ace4feffef46dae3b48340931cc1e_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_681ace4feffef46dae3b48340931cc1e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_681ace4feffef46dae3b48340931cc1e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_681ace4feffef46dae3b48340931cc1e = L.geoJson(null, {
#                 onEachFeature: geo_json_681ace4feffef46dae3b48340931cc1e_onEachFeature,
#
#                 style: geo_json_681ace4feffef46dae3b48340931cc1e_styler,
#                 pointToLayer: geo_json_681ace4feffef46dae3b48340931cc1e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_681ace4feffef46dae3b48340931cc1e_add (data) {
#             geo_json_681ace4feffef46dae3b48340931cc1e
#                 .addData(data);
#         }
#             geo_json_681ace4feffef46dae3b48340931cc1e_add({&quot;bbox&quot;: [4.7853145, 45.7292496, 4.879019300000001, 45.79182229999999], &quot;features&quot;: [{&quot;bbox&quot;: [4.834071600000001, 45.7292496, 4.855947199999999, 45.73279900000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[4.855947199999999, 45.73279900000001], [4.855942, 45.7327624], [4.855

# %% [markdown]
# See the [Usage docs](https://docs.bikenetkit.org/GrowBikeNet/usage/) for detailed explanations.
